# %% [markdown]
# # Verify files containing special characters and Emoji's

# %%
df = spark.read.parquet("Files/SpecialCharSet/CrSpCharFromSpk")
df.show()
df.printSchema()
# Out:
# StatementMeta(, 505fbb3a-c6f0-41a1-810e-7cff24ca6c5a, 3, Finished, Available, Finished, False)
# +-----------+--------------------+
# |       name|            feedback|
# +-----------+--------------------+
# |     Bob ❤️|Needs improvement...|
# |Frank & Co.|   Good effort 💪🏋️|
# |  Charlie ©|  Excellent work 🌟✨|
# |    David ®|      Well done 👏🙌|
# |      Eve ™|       Awesome! 🚀🌌|
# |   Alice 😊|     Great job! 👍😀|
# |    Henry $|    Impressive 😎🕶️|
# |      Ivy %|         Superb 🌈☁️|
# |     Jack *|    Outstanding 🏆🥇|
# |   Grace #1|      Fantastic 🎉🥳|
# +-----------+--------------------+
#
# root
#  |-- name: string (nullable = true)
#  |-- feedback: string (nullable = true)

# %% [markdown]
# # Sepcial Characters and Emoji's in CSV

# %%
df = spark.read.csv("Files/SpecialCharSet/CustomerFeedback_Sample.csv")
display(df)
df.printSchema()
# Out:
# StatementMeta(, 505fbb3a-c6f0-41a1-810e-7cff24ca6c5a, 6, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1b2ecf2a-26b2-4376-a784-b70ed663cda8)
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)

# %%
df = spark.read.format("csv").option("header","true").load("Files/SpecialCharSet/splCharacters.csv")
# df now is a Spark DataFrame containing CSV data from "Files/SpecialCharSet/splCharacters.csv".
display(df)
# Out:
# StatementMeta(, 505fbb3a-c6f0-41a1-810e-7cff24ca6c5a, 8, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c3102f96-508e-4d96-b09a-65f5b54ccdf0)
